# %%
import time
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import RandomOverSampler

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.utils import resample

# %%
df = pd.read_csv("C:\\Users\\aeaea\\OneDrive\\سطح المكتب\\ml_features_and_labels.csv")
df.head()

manifest = pd.read_csv("C:\\Users\\aeaea\\OneDrive\\سطح المكتب\\scenario_manifest.csv")

df['merge_id'] = df['ID'].astype(str).str.replace('.pcap', '', regex=False)
manifest['merge_id'] = manifest['ID'].astype(str).str.replace('.pcap', '', regex=False)

manifest_features = manifest[['merge_id', 'taxonomy_class', 'run_idx']].copy()

df = df.merge(manifest_features, on='merge_id', how='left')

df = df.drop(columns=['merge_id'])

df.head()
# Out:
#    e2c_total_bytes  e4_entropy_h  e5_entropy_c  e6_time_char  \
# 0             8182        4.7889        5.8077          2.45
# 1             8126        5.0000        5.8367          2.44
# 2             8272        4.7889        5.9056          2.73
# 3             8272        4.8125        5.9056          2.31
# 4             8272        4.8125        5.8367          4.45
#
#    e6b_flow_duration_ms  e2_client_size  e2_client_record_len  \
# 0            149.827957            32.0                   285
# 1            231.020927            32.0                   285
# 2            292.967796            32.0                   285
# 3            156.050205            32.0                   285
# 4            193.972111            32.0                   285
#
#    e2_server_record_len  e3_cert_parsed  e1_alg_suite_Unknown(0x11eb)  ...  \
# 0                5316.0           False                         False  ...
# 1                5316.0           False                         False  ...
# 2                5316.0           False                         False  ...
# 3                5316.0           False                         False  ...
# 4                5316.0           False                         False  ...
#
#    e2b_tls_version_TLS1.0  e2b_ciphersuite_2  e2b_ciphersuite_54  \
# 0                    True              False               False
# 1                    True              False               False
# 2                    True              False               False
# 3                    True              False               False
# 4                    True              False               False
#
#    e2b_ciphersuite_60  label  split           taxonomy  \
# 0                True      1  train  eval_test_network
# 1                True      1    val  eval_test_network
# 2                True      1  train  eval_test_network
# 3                True      1   test  eval_test_network
# 4                True      1   test  eval_test_network
#
#                                ID  taxonomy_class  run_idx
# 0    net_high_jitter_classic_run1         Network        1
# 1   net_high_jitter_classic_run10         Network       10
# 2  net_high_jitter_classic_run100         Network      100
# 3  net_high_jitter_classic_run101         Network      101
# 4  net_high_jitter_classic_run102         Network      102
#
# [5 rows x 38 columns]

# %%
feature_columns = [col for col in df.columns if col not in ['label', 'split', 'taxonomy', 'ID']]
X = df[feature_columns].replace({True: 1, False: 0, 'TRUE': 1, 'FALSE': 0})
X = X.apply(pd.to_numeric, errors='coerce').fillna(0)
y = df['label']

X_train = X[df['split'] == 'train']
y_train = y[df['split'] == 'train']
X_val = X[df['split'] == 'val']
y_val = y[df['split'] == 'val']
X_test = X[df['split'] == 'test']
y_test = y[df['split'] == 'test']
# Out:
# C:\Users\aeaea\AppData\Local\Temp\ipykernel_17748\3880489625.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = df[feature_columns].replace({True: 1, False: 0, 'TRUE': 1, 'FALSE': 0})

# %%
from sklearn.ensemble import GradientBoostingClassifier

baseline_model = GradientBoostingClassifier(
    n_estimators=200,
    random_state=42
)

start = time.perf_counter()

baseline_model.fit(X_train, y_train)

baseline_train_time = time.perf_counter() - start

baseline_val_pred = baseline_model.predict(X_val)

print(f"Baseline training time: {baseline_train_time:.2f} seconds")
print("\nBaseline validation report:")
print(classification_report(y_val, baseline_val_pred, zero_division=0))
# Out:
# Baseline training time: 8.66 seconds
#
# Baseline validation report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      7000
#            1       0.90      0.90      0.90      1002
#
#     accuracy                           0.97      8002
#    macro avg       0.94      0.94      0.94      8002
# weighted avg       0.97      0.97      0.97      8002

# %%
start = time.perf_counter()
y_val_pred = baseline_model.predict(X_val)
y_test_pred = baseline_model.predict(X_test)
end = time.perf_counter()
testing_time = end - start

results = pd.DataFrame({
    'Split': ['Validation', 'Test'],
    'Accuracy': [accuracy_score(y_val, y_val_pred), accuracy_score(y_test, y_test_pred)],
    'Precision': [precision_score(y_val, y_val_pred, zero_division=0), precision_score(y_test, y_test_pred, zero_division=0)],
    'Recall': [recall_score(y_val, y_val_pred, zero_division=0), recall_score(y_test, y_test_pred, zero_division=0)],
    'F1 Score': [f1_score(y_val, y_val_pred, zero_division=0), f1_score(y_test, y_test_pred, zero_division=0)]
})

print(f'Testing time: {testing_time:.2f} seconds')
print('Test classification report:')
print(classification_report(y_test, y_test_pred, zero_division=0))
results
# Out:
# Testing time: 0.07 seconds
# Test classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      7000
#            1       0.88      0.90      0.89      1002
#
#     accuracy                           0.97      8002
#    macro avg       0.93      0.94      0.94      8002
# weighted avg       0.97      0.97      0.97      8002
#         Split  Accuracy  Precision    Recall  F1 Score
# 0  Validation  0.974256   0.895626  0.899202  0.897410
# 1        Test  0.972507   0.882583  0.900200  0.891304
